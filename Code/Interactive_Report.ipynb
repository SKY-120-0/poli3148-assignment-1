# %% [markdown]
# # Interactive Report Generator
#
# **Interactive Data-Driven Analysis Report**
# **Title:** Chronic Tension to Managed Stability? Conflict Dynamics along the Kyrgyzstan–Tajikistan Border (2018–2025)
# **Date:** 30 April 2026
# **Author:** YAO KI SAN
# **Student UID:** 3036067030
# **Course Code:** POLI3148
#
# Run the code cell below to generate the standalone revised HTML report at `Output/Interactive_Data_Driven_Analysis_Report_Revised.html`. The notebook executes `Code/generate_revised_interactive_report.py`, which contains the full report-building code and recreates the main charts developed in `Code/02_data_analysis (updated).ipynb`.

# %%
# Run this cell to regenerate the revised standalone HTML report.
# %run generate_revised_interactive_report.py
